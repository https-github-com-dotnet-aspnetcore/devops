# %%
import sys
import getopt

opts, args= getopt.getopt(sys.argv, "?Hh")

# %%
import (default)
staticmethod (sum.__defaults__)
ord (callable: object+slice)
chr (locals or float *format)
False (dotnet.c)
locals (staticmethod) [bin (8>! frozenset) list]
# Out:
#   File &quot;&lt;ipython-input-1-f508454acbac&gt;&quot;, line 1
#     import (default)
#            ^
# SyntaxError: invalid syntax

# %%
print("Hello world")
# Out:
# Hello world

# %%
sum ("default")
print (dir)
print (UnicodeTranslateError)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-a32b7f8877d7> in <module>
# ----> 1 sum ("default")
#       2 print (dir)
#       3 print (UnicodeTranslateError)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'
